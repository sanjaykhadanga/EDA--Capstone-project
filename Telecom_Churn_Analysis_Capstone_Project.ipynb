# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjaykhadanga/EDA--Capstone-project/blob/main/Telecom_Churn_Analysis_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <b> Orange S.A., formerly France Télécom S.A., is a French multinational telecommunications corporation. The Orange Telecom's Churn Dataset, consists of cleaned customer activity data (features), along with a churn label specifying whether a customer canceled the subscription.
#
# ## <b> Explore and analyze the data to discover key factors responsible for customer churn and come up with ways/recommendations to ensure customer retention. </b>

# %% [markdown]
# **understand more about the data**

# %%
#importing the required packages
import pandas as pd
import numpy as np
#import visualization packages
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#mount the drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#insert the data file 
working_dir_path='/content/drive/MyDrive/Projects AlmaBetter/EDA Project/'
telecom_df= pd.read_csv(working_dir_path + 'Telecom Churn.csv')

# %%
# Viewing the data of top 5 rows to look the glimps of the data
telecom_df.head(5)
# Out:
#   State  Account length  ...  Customer service calls  Churn
# 0    KS             128  ...                       1  False
# 1    OH             107  ...                       1  False
# 2    NJ             137  ...                       0  False
# 3    OH              84  ...                       2  False
# 4    OK              75  ...                       3  False
#
# [5 rows x 20 columns]

# %%
# View the data of bottom 5 rows to look the glimps of the data
telecom_df.tail(5)
# Out:
#      State  Account length  ...  Customer service calls  Churn
# 3328    AZ             192  ...                       2  False
# 3329    WV              68  ...                       3  False
# 3330    RI              28  ...                       2  False
# 3331    CT             184  ...                       2  False
# 3332    TN              74  ...                       0  False
#
# [5 rows x 20 columns]

# %%
#Getting the shape of dataset with rows and columns
print(telecom_df.shape)
# Out:
# (3333, 20)

# %%
#Getting all the columns
telecom_df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
#Getting the data types of all the columns
telecom_df.dtypes
# Out:
# State                      object
# Account length              int64
# Area code                   int64
# International plan         object
# Voice mail plan            object
# Number vmail messages       int64
# Total day minutes         float64
# Total day calls             int64
# Total day charge          float64
# Total eve minutes         float64
# Total eve calls             int64
# Total eve charge          float64
# Total night minutes       float64
# Total night calls           int64
# Total night charge        float64
# Total intl minutes        float64
# Total intl calls            int64
# Total intl charge         float64
# Customer service calls      int64
# Churn                        bool
# dtype: object

# %%
#check details about the data set
telecom_df.info()
#we see that we have 3333 entries and no null values are present
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
#  14  Total night charge      3333 non-null   float64
#  15  Total intl minutes      3333 non-null   float64
#  16  Total intl calls        3333 non-null   int64
#  17  Total intl charge       3333 non-null   float64
#  18  Customer service calls  3333 non-null   int64
#  19  Churn                   3333 non-null   bool
# dtypes: bool(1), float64(8), int64(8), object(3)
# memory usage: 498.1+ KB

# %%
telecom_df.nunique()
# Out:
# State                       51
# Account length             212
# Area code                    3
# International plan           2
# Voice mail plan              2
# Number vmail messages       46
# Total day minutes         1667
# Total day calls            119
# Total day charge          1667
# Total eve minutes         1611
# Total eve calls            123
# Total eve charge          1440
# Total night minutes       1591
# Total night calls          120
# Total night charge         933
# Total intl minutes         162
# Total intl calls            21
# Total intl charge          162
# Customer service calls      10
# Churn                        2
# dtype: int64

# %%
#Printing the count of true and false in 'churn' feature
print(telecom_df.Churn.value_counts())
# Out:
# False    2850
# True      483
# Name: Churn, dtype: int64

# %%
#To get the pie chart to analyze churn
telecom_df ['Churn'].value_counts().plot.pie(explode=[0.05,0.05], autopct='%1.1f%%', shadow=True, figsize=(8,8))
plt.title('Pie Chart for Churn')
plt.show()

# %%
#Looking for the description of the dataset to get insights of the data
telecom_df.describe(include='all')
# Out:
#        State  Account length  ...  Customer service calls  Churn
# count   3333     3333.000000  ...             3333.000000   3333
# unique    51             NaN  ...                     NaN      2
# top       WV             NaN  ...                     NaN  False
# freq     106             NaN  ...                     NaN   2850
# mean     NaN      101.064806  ...                1.562856    NaN
# std      NaN       39.822106  ...                1.315491    NaN
# min      NaN        1.000000  ...                0.000000    NaN
# 25%      NaN       74.000000  ...                1.000000    NaN
# 50%      NaN      101.000000  ...                1.000000    NaN
# 75%      NaN      127.000000  ...                2.000000    NaN
# max      NaN      243.000000  ...                9.000000    NaN
#
# [11 rows x 20 columns]

# %% [markdown]
# ### **Checking for Missing values**

# %%
#check for count of missing values in each column.
telecom_df.isna().sum()
telecom_df.isnull().sum()
#as we see there are no missing values present in nay column.
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %%
missing = pd.DataFrame((telecom_df.isnull().sum())*100/telecom_df.shape[0]).reset_index()
plt.figure(figsize=(16,5))
ax = sns.pointplot('index',0,data=missing)
plt.xticks(rotation =90,fontsize =7)
plt.title("Percentage of Missing values")
plt.ylabel("PERCENTAGE")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Drop Account Length as it doesnt make an effect on dependent variable 
telecom_df_new = telecom_df.drop('Account length',axis=1)
telecom_df_new.head()
# Out:
#   State  Area code  ... Customer service calls  Churn
# 0    KS        415  ...                      1  False
# 1    OH        415  ...                      1  False
# 2    NJ        415  ...                      0  False
# 3    OH        408  ...                      2  False
# 4    OK        415  ...                      3  False
#
# [5 rows x 19 columns]

# %% [markdown]
# ### **Univariate Analysis**

# %%
###Univariate analysis
#Box plot for Number voice mails messages
fig = plt.figure(figsize =(8, 6)) 
telecom_df.boxplot(column =['Number vmail messages'])
# show plot
plt.show()

# %%
#Box plot on daily minutes,calls,charge
fig = plt.figure(figsize =(8, 6)) 
telecom_df.boxplot(column =['Total day minutes', 'Total eve minutes', 'Total night minutes'])
fig.suptitle('Minute call data', fontsize=14, fontweight='bold')
plt.ylabel('Minutes')
# show plot
plt.show()

# %%
#Box plot on Total Calls
fig = plt.figure(figsize =(8, 6)) 
telecom_df.boxplot(column =[ 'Total day calls','Total eve calls','Total night calls'])
fig.suptitle('Total Calls', fontsize=14, fontweight='bold')
plt.ylabel('Count')
# show plot
plt.show()

# %%
#Box plot on Charges
fig = plt.figure(figsize =(8, 6)) 
telecom_df.boxplot(column =[ 'Total day charge','Total eve charge','Total night charge'])
fig.suptitle('Charge for calls', fontsize=14, fontweight='bold')
plt.ylabel('Count')
# show plot
plt.show()

# %%
#Box plot on International calls
fig = plt.figure(figsize =(8, 6)) 
telecom_df.boxplot(column =['Total intl minutes','Total intl calls','Total intl charge'])
fig.suptitle('International call data', fontsize=14, fontweight='bold')
plt.ylabel('Values')
# show plot
plt.show()

# %%
#Box plot on Customer service calls
fig = plt.figure(figsize =(8, 6)) 
telecom_df.boxplot(column =['Customer service calls'])
fig.suptitle('Customer service calls', fontsize=14, fontweight='bold')
plt.ylabel('Values')
# show plot
plt.show()

# %% [markdown]
# ## **Bivariate analysis**

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(15,8))
ax = sns.countplot(x='State', hue="Churn", data=telecom_df)
plt.show()

# %%
sns.set(style="darkgrid")
ax = sns.countplot(x='Area code', hue="Churn", data=telecom_df)
plt.show()

# %%
telecom_df_new.boxplot(column='Number vmail messages', by='Churn')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
plt.show()
telecom_df_new.boxplot(column='Total day minutes', by='Churn')
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
plt.show()
telecom_df_new.boxplot(column='Total day calls', by='Churn')
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
plt.show()
telecom_df_new.boxplot(column='Total day charge', by='Churn')
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
plt.show()
telecom_df_new.boxplot(column='Total eve minutes', by='Churn')
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
plt.show()
telecom_df_new.boxplot(column='Total eve calls', by='Churn')
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
plt.show()
telecom_df_new.boxplot(column='Total eve charge', by='Churn')
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
plt.show()
telecom_df_new.boxplot(column='Total night minutes', by='Churn')
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
plt.show()
telecom_df_new.boxplot(column='Total night calls', by='Churn')
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
plt.show()
telecom_df_new.boxplot(column='Total night charge', by='Churn')
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
plt.show()
telecom_df_new.boxplot(column='Total intl minutes', by='Churn')
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
plt.show()
telecom_df_new.boxplot(column='Total intl calls', by='Churn')
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
plt.show()
telecom_df_new.boxplot(column='Total intl charge', by='Churn')
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
#Relation between Churn and Customer service calls
telecom_df_new.boxplot(column='Customer service calls', by='Churn')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
sns.set(style="darkgrid")
ax = sns.countplot(x='Customer service calls', hue="Churn", data=telecom_df)
plt.show()

# %% [markdown]
# ### **Multi variate analysis**

# %%
plt.figure(figsize=(12,12))
sns.heatmap(telecom_df.corr(), cmap="Paired",annot=False)

# %%
corr = telecom_df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_a440f240_1c97_11ec_9008_0242ac1c0002row0_col0,#T_a440f240_1c97_11ec_9008_0242ac1c0002row1_col1,#T_a440f240_1c97_11ec_9008_0242ac1c0002row2_col2,#T_a440f240_1c97_11ec_9008_0242ac1c0002row3_col3,#T_a440f240_1c97_11ec_9008_0242ac1c0002row3_col5,#T_a440f240_1c97_11ec_9008_0242ac1c0002row4_col4,#T_a440f240_1c97_11ec_9008_0242ac1c0002row5_col3,#T_a440f240_1c97_11ec_9008_0242ac1c0002row5_col5,#T_a440f240_1c97_11ec_9008_0242ac1c0002row6_col6,#T_a440f240_1c97_11ec_9008_0242ac1c0002row6_col8,#T_a440f240_1c97_11ec_9008_0242ac1c0002row7_col7,#T_a440f240_1c97_11ec_9008_0242ac1c0002row8_col6,#T_a440f240_1c97_11ec_9008_0242ac1c0002row8_col8,#T_a440f240_1c97_11ec_9008_0242ac1c0002row9_col9,#T_a440f240_1c97_11ec_9008_0242ac1c0002row9_col11,#T_a440f240_1c97_11ec_9008_0242ac1c0002row10_col10,#T_a440f240_1c97_11ec_9008_0242ac1c0002row11_col9,#T_a440f240_1c97_11ec_9008_0242ac1c0002row11_col11,#T_a440f240_1c97_11ec_9008_0242ac1c0002row12_col12,#T_a440f240_1c97_11ec_9008_0242ac1c0002row12_col14,#T_a440f240_1c97_11ec_9008_0242ac1c0002row13_col13,#T_a440f240_1c97_11ec_9008_0242ac1c0002row14_col12,#T_a440f240_1c97_11ec_9008_0242ac1c0002row14_col14,#T_a440f240_1c97_11ec_9008_0242ac1c0002row15_col15,#T_a440f240_1c97_11ec_9008_0242ac1c0002row16_col16{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_a440f240_1c97_11ec_9008_0242ac1c0002row0_col1,#T_a440f240_1c97_11ec_9008_0242ac1c0002row1_col4,#T_a440f240_1c97_11ec_9008_0242ac1c0002row1_col9,#T_a440f240_1c97_11ec_9008_0242ac1c0002row1_col11,#T_a440f240_1c97_11ec_9008_0242ac1c0002row2_col0,#T_a440f240_1c97_11ec_9008_0242ac1c0002row2_col4,#T_a440f240_1c97_11ec_9008_0242ac1c0002row3_col12,#T_a440f240_1c97_11ec_9008_0242ac1c0002row3_col14,#T_a440f240_1c97_11ec_9008_0242ac1c0002row5_col12,#T_a440f240_1c97_11ec_9008_0242ac1c0002row5_col14,#T_a440f240_1c97_11ec_9008_0242ac1c0002row7_col6,#T_a440f240_1c97_11ec_9008_0242ac1c0002row7_col8,#T_a440f240_1c97_11ec_9008_0242ac1c0002row9_col6,#T_a440f240_1c97_11ec_9008_0242ac1c0002row9_col7,#T_a440f240_1c97_11ec_9008_0242ac1c0002row9_col8,#T_a440f240_1c97_11ec_9008_0242ac1c0002row9_col15,#T_a440f240_1c97_11ec_9008_0242ac1c0002row11_col6,#T_a440f240_1c97_11ec_9008_0242ac1c0002row11_col7,#T_a440f240_1c97_11ec_9008_0242ac1c0002row11_col8,#T_a440f240_1c97_11ec_9008_0242ac1c0002row11_col15,#T_a440f240_1c97_11ec_9008_0242ac1c0002row12_col6,#T_a440f240_1c97_11ec_9008_0242ac1c0002row12_col8,#T_a440f240_1c97_11ec_9008_0242ac1c0002row12_col15,#T_a440f240_1c97_11ec_9008_0242ac1c0002row14_col6,#T_a440f240_1c97_11ec_9008_0242ac1c0002row14_col8,#T_a440f240_1c97_11ec_9008_0242ac1c0002row14_col15,#T_a440f240_1c97_11ec_9008_0242ac1c0002row15_col0,#T_a440f240_1c97_11ec_9008_0242ac1c0002row15_col6,#T_a440f240_1c97_11ec_9008_0242ac1c0002row15_col8,#T_a440f240_1c97_11ec_9008_0242ac1c0002row15_col12,#T_a440f240_1c97_11ec_9008_0242ac1c0002row15_col14{
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }#T_a440f240_1c97_11ec_9008_0242ac1c0002row0_col2,#T_a440f240_1c97_11ec_9008_0242ac1c0002row7_col2{
#             background-color:  #516ddb;
#             color:  #000000;
#         }#T_a440f240_1c97_11ec_9008_0242ac1c0002row0_col3,#T_a440f240_1c97_11ec_9008_0242ac1c0002row0_col5,#T_a440f240_1c97_11ec_9008_0242ac1c0002row3_col0,#T_a440f240_1c97_11ec_9008_0242ac1c0002row3_col9,#T_a440f240_1c97_11ec_9008_0242ac1c0002row3_col11,#T_a440f240_1c97_11ec_9008_0242ac1c0002row4_col7,#T_a440f240_1c97_11ec_9008_0242ac1c0002row5_col0,#T_a440f240_1c97_11ec_9008_0242ac1c0002row5_col9,#T_a440f240_1c97_11ec_9008_0242ac1c0002row5_col11,#T_a440f240_1c97_11ec_9008_0242ac1c0002row9_col1,#T_a440f240_1c97_11ec_9008_0242ac1c0002row9_col3,#T_a440f240_1c97_11ec_9008_0242ac1c0002row9_col5,#T_a440f240_1c97_11ec_9008_0242ac1c0002row10_col7,#T_a440f240_1c97_11ec_9008_0242ac1c0002row11_col1,#T_a440f240_1c97_11ec_9008_0242ac1c0002row11_col3,#T_a440f240_1c97_11ec_9008_0242ac1c0002row11_col5,#T_a440f240_1c97_11ec_9008_0242ac1c0002row13_col10{
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }#T_a440f240_1c97_11ec_9008_0242ac1c0002row0_col4{
#             background-color:  #4c66d6;
#             color:  #000000;
#         }#T_a440f240_1c97_11ec_9008_0242ac1c0002row0_col6,#T_a440f240_1c97_11ec_9008_0242ac1c0002row0_col8,#T_a440f240_1c97_11ec_9008_0242ac1c0002row0_col15,#T_a440f240_1c97_11ec_9008_0242ac1c0002row2_col3,#T_a440f240_1c97_11ec_9008_0242ac1c0002row2_col5,#T_a440f240_1c97_11ec_9008_0242ac1c0002row3_col1,#T_a440f240_1c97_11ec_9008_0242ac1c0002row4_col1,#T_a440f240_1c97_11ec_9008_0242ac1c0002row5_col1,#T_a440f240_1c97_11ec_9008_0242ac1c0002row7_col1,#T_a440f240_1c97_11ec_9008_0242ac1c0002row7_col9,#T_a440f240_1c97_11ec_9008_0242ac1c0002row7_col11,#T_a440f240_1c97_11ec_9008_0242ac1c0002row15_col7{
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }#T_a440f240_1c97_11ec_9008_0242ac1c0002row0_col7,#T_a440f240_1c97_11ec_9008_0242ac1c0002row0_col14,#T_a440f240_1c97_11ec_9008_0242ac1c0002row3_col4,#T_a440f240_1c97_11ec_9008_0242ac1c0002row3_col6,#T_a440f240_1c97_11ec_9008_0242ac1c0002row3_col8,#T_a440f240_1c97_11ec_9008_0242ac1c0002row5_col4,#T_a440f240_1c97_11ec_9008_0242ac1c0002row5_col6,#T_a440f240_1c97_11ec_9008_0242ac1c0002row5_col8,#T_a440f240_1c97_11ec_9008_0242ac1c0002row7_col3,#T_a440f240_1c97_11ec_9008_0242ac1c0002row7_col5,#T_a440f240_1c97_11ec_9008_0242ac1c0002row9_col10,#T_a440f240_1c97_11ec_9008_0242ac1c0002row10_col6,#T_a440f240_1c97_11ec_9008_0242ac1c0002row10_col8,#T_a440f240_1c97_11ec_9008_0242ac1c0002row11_col10,#T_a440f240_1c97_11ec_9008_0242ac1c0002row13_col7,#T_a440f240_1c97_11ec_9008_0242ac1c0002row16_col0,#T_a440f240_1c97_11ec_9008_0242ac1c0002row16_col1{
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }#T_a440f240_1c97_11ec_9008_0242ac1c0002row0_col9,#T_a440f240_1c97_11ec_9008_0242ac1c0002row0_col10,#T_a440f240_1c97_11ec_9008_0242ac1c0002row0_col11,#T_a440f240_1c97_11ec_9008_0242ac1c0002row1_col3,#T_a440f240_1c97_11ec_9008_0242ac1c0002row1_col5,#T_a440f240_1c97_11ec_9008_0242ac1c0002row2_col7,#T_a440f240_1c97_11ec_9008_0242ac1c0002row2_col15,#T_a440f240_1c97_11ec_9008_0242ac1c0002row3_col15,#T_a440f240_1c97_11ec_9008_0242ac1c0002row5_col15,#T_a440f240_1c97_11ec_9008_0242ac1c0002row6_col0,#T_a440f240_1c97_11ec_9008_0242ac1c0002row6_col12,#T_a440f240_1c97_11ec_9008_0242ac1c0002row6_col14,#T_a440f240_1c97_11ec_9008_0242ac1c0002row6_col15,#T_a440f240_1c97_11ec_9008_0242ac1c0002row8_col0,#T_a440f240_1c97_11ec_9008_0242ac1c0002row8_col12,#T_a440f240_1c97_11ec_9008_0242ac1c0002row8_col14,#T_a440f240_1c97_11ec_9008_0242ac1c0002row8_col15,#T_a440f240_1c97_11ec_9008_0242ac1c0002row9_col0,#T_a440f240_1c97_11ec_9008_0242ac1c0002row10_col12,#T_a440f240_1c97_11ec_9008_0242ac1c0002row10_col14,#T_a440f240_1c97_11ec_9008_0242ac1c0002row10_col15,#T_a440f240_1c97_11ec_9008_0242ac1c0002row11_col0,#T_a440f240_1c97_11ec_9008_0242ac1c0002row12_col1,#T_a440f240_1c97_11ec_9008_0242ac1c0002row12_col10,#T_a440f240_1c97_11ec_9008_0242ac1c0002row14_col1,#T_a440f240_1c97_11ec_9008_0242ac1c0002row14_col10,#T_a440f240_1c97_11ec_9008_0242ac1c0002row15_col9,#T_a440f240_1c97_11ec_9008_0242ac1c0002row15_col10,#T_a440f240_1c97_11ec_9008_0242ac1c0002row15_col11{
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }#T_a440f240_1c97_11ec_9008_0242ac1c0002row0_col12,#T_a440f240_1c97_11ec_9008_0242ac1c0002row1_col6,#T_a440f240_1c97_11ec_9008_0242ac1c0002row1_col8,#T_a440f240_1c97_11ec_9008_0242ac1c0002row1_col13,#T_a440f240_1c97_11ec_9008_0242ac1c0002row2_col10,#T_a440f240_1c97_11ec_9008_0242ac1c0002row3_col7,#T_a440f240_1c97_11ec_9008_0242ac1c0002row5_col7,#T_a440f240_1c97_11ec_9008_0242ac1c0002row6_col1,#T_a440f240_1c97_11ec_9008_0242ac1c0002row6_col10,#T_a440f240_1c97_11ec_9008_0242ac1c0002row7_col4,#T_a440f240_1c97_11ec_9008_0242ac1c0002row7_col10,#T_a440f240_1c97_11ec_9008_0242ac1c0002row7_col12,#T_a440f240_1c97_11ec_9008_0242ac1c0002row7_col14,#T_a440f240_1c97_11ec_9008_0242ac1c00
